# %% [markdown]
# ### Style and choice of graph to learn.
# - one style of figure i would like to learn is how to create hat graphs.
# - A hat plot can be useful for comparing the distribution of a variable across different categories or subgroups.
#
# For example, we could create a hat plot with the following structure:
#
# To visually compare the distributions of immigration phobia feelings between males and females.
#
# We could build hat plots to make  visual distribution comparisons across other variable pairs as well, like age groups, education levels.
#
# The hat plot lets us move beyond comparing just summary statistics between groups and instead visually assess differences or similarities in response densities and spread. This can reveal insights on whether certain groups exhibit stronger clustering or outliers in their attitudinal survey responses.
#
# Let me know if you have any other questions!

# %%
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np

# %%
cces_Examples = pd.read_csv("C:\\Users\\Jay\\Interactive Data\\cces_example_data.csv")
cces_Examples
# Out:
#      sex  educ  nonwhite  age  ImmiPhobia  ConMediaUse  Real_Threat  \
# 0      2     2         1   56         1.0     1.000000         5.00
# 1      2     5         1   53         1.0     2.000000         5.00
# 2      1     2         1   69         3.5     1.000000         5.00
# 3      1     6         1   76         1.0     1.333333         4.25
# 4      2     6         1   83         1.0     3.666667         4.25
# ..   ...   ...       ...  ...         ...          ...          ...
# 654    2     2         2   30         2.0     1.666667         3.00
# 655    1     4         1   19         1.0     1.000000         3.75
# 656    1     3         1   20         1.0     4.666667         5.00
# 657    1     3         1   23         2.5     2.333333         2.50
# 658    1     3         1   23         2.5     2.333333         2.50
#
#      Evaluation
# 0             0
# 1             0
# 2             2
# 3             0
# 4             0
# ..          ...
# 654           3
# ...

# %%
# figures with 2 axes
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(10, 4))

# Set title for the first axis
ax1.set_title("Age Histogram")

# Set title for the second axis
ax2.set_title("Political Identity")

# Show the empty figure
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 6))

# Create a bar plot for the 'Evaluation' variable
cces_Examples['Evaluation'].value_counts().sort_index().plot(kind='bar', ax=ax, color='skyblue')

# Set labels and title
ax.set_xlabel('Evaluation')
ax.set_ylabel('Count')
ax.set_title('Bar Plot of Evaluation Variable')

# Show the figure
plt.show()

# %%
# Scatterplot

N = len(cces_Examples)  

x = cces_Examples['ConMediaUse'].values
y = cces_Examples['ImmiPhobia'].values

c = np.random.randint(1, 7, size=N) 

s = np.random.randint(10, 400, size=N)  

fig, ax = plt.subplots()

scatter = ax.scatter(x, y, c=c, s=s)

# produce color legend  
legend1 = ax.legend(*scatter.legend_elements(), 
                   loc="lower left",title="Classes") 
ax.add_artist(legend1)

# produce size legend
handles, labels = scatter.legend_elements(prop="sizes", alpha=0.6)

legend2 = ax.legend(handles, labels, loc="upper right", title="Sizes") 

plt.xlabel('Conservative Media Use')
plt.ylabel('Immigration Phobia')
plt.title("Conservative Media Use vs Immigration Phobia")  

plt.show()
